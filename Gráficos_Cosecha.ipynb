# %%
# apertura de archivo excel
import pandas as pd

# abrir data framede excel
df=pd.read_excel(r'C:\Users\paula\OneDrive - Universidad EARTH\Desktop\Chiven\Chiven\Deberes Universidad\IV AÑO\progra\cosecha2021.xlsx')

# %%
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

# %%
# ordenamiento de los datos

df_categoria=df.groupby('tratamiento').mean('rendimientogrm2')
print(df_categoria)
print("***************")
# Out:
#              1000granos_gr  rendimiento_grm2  5tallos_hum  5tallos_sec_gr  \
# tratamiento
# F100                  22.8             619.2         49.2           28.47
# F100MO                22.4             567.8         41.8           26.92
# F130                  22.5             650.0         43.2           27.24
# F130MO                24.7             661.8         43.6           27.05
# T                     22.5             510.4         40.6           26.40
# TMO                   22.6             590.8         43.4           27.17
#
#              grano_panicula_gr  granosvanos_panicula
# tratamiento
# F100                     117.1                  34.1
# F100MO                    96.3                  60.1
# F130                     113.2                  52.3
# F130MO                   133.1                  34.6
# T                         98.3                  56.2
# TMO                      104.7                  50.7
# ***************

# %%
#generación de gráficos de box-plot
fig =plt.figure(figsize=(8,4))
ax = fig.add_subplot(111)

ax=sns.boxplot(x='tratamiento', y='rendimiento_grm2', data=df)
ax1=plt.scatter(df['tratamiento'],df['rendimiento_grm2'])
plt.ylabel('rendimiento gr/m2')
plt.xlabel('tratamiento')
plt.title('Comparación de medias')
plt.grid(True)
plt.show()

# %%
#### 4 gráfcos boxplot en cuadrícula

fig =plt.figure(figsize=(10,10))

#g1
ax = fig.add_subplot(221)

ax=sns.boxplot(x='tratamiento', y='1000granos_gr', data=df, color='grey')
ax.legend()
plt.ylabel('1000granos_gr')
plt.xlabel('tratamiento')
plt.title('Gráfico de BoxPlot')

#g2
ax2 = fig.add_subplot(222)
ax2=sns.boxplot(x='tratamiento', y='5tallos_hum', data=df, color='grey')
plt.ylabel('5tallos_hum')
plt.xlabel('tratamiento')
plt.title('Gráfico de BoxPlot')

#g3
ax3 = fig.add_subplot(223)

ax3=sns.boxplot(x='tratamiento', y='5tallos_sec_gr', data=df, color='grey')
plt.ylabel('5tallos_sec_gr')
plt.xlabel('tratamiento')
plt.title('Gráfico de BoxPlot')

#g4
ax4 = fig.add_subplot(224)

ax4=sns.boxplot(x='tratamiento', y='grano_panicula_gr', data=df, color='grey')
plt.ylabel('grano_panicula_gr')
plt.xlabel('tratamiento')
plt.title('Gráfico de BoxPlot')

plt.show
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <function matplotlib.pyplot.show(close=None, block=None)>
